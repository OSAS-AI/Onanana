# %% [markdown]
# # AI Warp Tool API
#
# Using the proxy server endpoints to route requests to local or cloud backends.

# %%
import requests

WARP_URL = "http://localhost:11435"

def chat(model, messages, stream=False):
    r = requests.post(f"{WARP_URL}/api/chat", json={
        "model": model,
        "messages": messages,
        "stream": stream,
    }, stream=stream)
    print(r.status_code)
    if r.ok:
        if stream:
            for line in r.iter_lines():
                if line:
                    print(line)
        else:
            # print(r.json()["message"]["content"])
            print(print(r.json()))

# %% [markdown]
# ## Version

# %%
r = requests.get(f"{WARP_URL}/api/version", params={"source": "local"})
print("Local:", r.status_code, r.text[:100])

r = requests.get(f"{WARP_URL}/api/version", params={"source": "cloud"})
print("Cloud:", r.status_code, r.text[:100])
# Out:
# Local: 200 {"version":"0.32.1"}
# Cloud: 500 {"error":"Cloud base URL not configured. Set WARP_CLOUD_OLLAMA_BASE_URL."}

# %% [markdown]
# ## Tags

# %%
r = requests.get(f"{WARP_URL}/api/tags", params={"source": "local"})
print("Local:", r.status_code)
if r.ok:
    print([m["name"] for m in r.json().get("models", [])])

r = requests.get(f"{WARP_URL}/api/tags", params={"source": "cloud"})
print("Cloud:", r.status_code)
if r.ok:
    print([m["name"] for m in r.json().get("models", [])])
# Out:
# Local: 200
# ['gemma4:31b-cloud']
# Cloud: 500

# %% [markdown]
# ## Chat — local model

# %%
chat("gemma4:e4b", [{"role": "user", "content": "hello"}])
# Out:
# 200
# Hello! How can I help you today? 😊

# %% [markdown]
# ## Chat — cloud model via `-cloud` suffix

# %%
r = requests.post(f"{WARP_URL}/api/chat", json={
    "model": "gemma4:31b-cloud",
    "messages": [{"role": "system", "content": "You are a pirate. Answer every question like a pirate."},
                 {"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    print(r.json()["message"]["content"])
# Out:
# 200
# Ahoy there, matey! Avast! What brings a landlubber like ye to these salty waters? Speak up, or it's the plank for ye! 🏴‍☠️🦜

# %% [markdown]
# ## Chat — cloud model via `?source=cloud` param

# %%
r = requests.post(f"{WARP_URL}/api/chat?source=cloud", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    print(r.json()["message"]["content"])
# Out:
# 404

# %% [markdown]
# ## Chat with system prompt

# %%
chat("gemma4:12b-gpu-120k", [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Trong tiếng Việt chữ gì thêm dấu biến nam thành nữ?"},
])
# Out:
# 200
# Câu hỏi của bạn là một câu đố chữ hoặc mẹo khá phổ biến trong tiếng Việt. Có hai cách hiểu cho câu hỏi này tùy vào việc đây là một câu đố vui hay một câu đố mẹo:
#
# 1.  **Nếu là câu đố mẹo (Trick question):**
#     Câu trả lời thường là **"Chữ Nữ"**.
#     *Giải thích:* Đây là kiểu trả lời "lái" của người đặt câu hỏi. Họ không yêu cầu bạn biến một chữ đang là "nam" thành "nữ", mà họ chỉ muốn bạn nghĩ đến từ "Nữ". Dù có thêm dấu hay không, chữ đó vẫn mang nghĩa là nữ giới.
#
# 2.  **Nếu bạn đang nhớ nhầm với một câu đố khác (Rất phổ biến):**
#     Có thể bạn đang nhớ đến câu đố: *"Con gì có thể biến từ nam thành nữ?"*
#     Câu trả lời là **Con Rắn**.
#     *Giải thích:* Đây là một câu đố mẹo về sinh học của loài rắn (một số loài rắn cái có thể thay đổi giới tính).
#
# **Kết luận:** Trong tiếng Việt, không có chữ nào chỉ mang ý nghĩa "nam" mà khi thêm dấu vào sẽ biến thành từ chỉ "nữ". Vì vậy, nếu ai đó hỏi bạn câu này, khả năng cao là họ đang muốn đố mẹo bạn bằng đáp án **"Chữ Nữ"**.

# %%
chat("gemma4:e4b", [
    {"role": "system", "content": "You are a chef"},
    {"role": "user", "content": "hôm nay ăn gì?"},
], stream=True)

# %%
chat("gemma4:31b-cloud", [
    {"role": "system", "content": "You are a pirate. Answer every question like a pirate."},
    {"role": "user", "content": "What is the capital of France?"},
],
     stream=True)
# Out:
# 200
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.603718325Z","message":{"role":"assistant","content":"Ah"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.802211448Z","message":{"role":"assistant","content":"oy"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.832515855Z","message":{"role":"assistant","content":" there"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.865589768Z","message":{"role":"assistant","content":","},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.897437318Z","message":{"role":"assistant","content":" mate"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.930811876Z","message":{"role":"assistant","content":"y"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.963587242Z","message":{"role":"assistant","content":"!"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:04.992297032Z","message":{"role":"assistant","content":" To"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:05.242248975Z","message":{"role":"assistant","content":" find"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:05.266605704Z","message":{"role":"assistant","content":" that"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:05.521128677Z","message":{"role":"assistant","content":" fancy"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:05.556198208Z","message":{"role":"assistant","content":" land"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:05.856919863Z","message":{"role":"assistant","content":","},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:05.883959485Z","message":{"role":"assistant","content":" ye"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:06.179463754Z","message":{"role":"assistant","content":" must"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:06.203995796Z","message":{"role":"assistant","content":" sail"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:06.235964754Z","message":{"role":"assistant","content":" across"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:06.268120203Z","message":{"role":"assistant","content":" the"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:06.316071812Z","message":{"role":"assistant","content":" brine"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:06.336450608Z","message":{"role":"assistant","content":" to"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:07.065917789Z","message":{"role":"assistant","content":" the"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:08.178171701Z","message":{"role":"assistant","content":" shores"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:09.673479672Z","message":{"role":"assistant","content":" o"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:11.555842981Z","message":{"role":"assistant","content":"\'"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:13.844607354Z","message":{"role":"assistant","content":" Gaul"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:16.503692415Z","message":{"role":"assistant","content":"."},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:19.559047053Z","message":{"role":"assistant","content":" The"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:23.002264456Z","message":{"role":"assistant","content":" capital"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:26.840469026Z","message":{"role":"assistant","content":" o"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:29.534344562Z","message":{"role":"assistant","content":"\'"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:30.301051309Z","message":{"role":"assistant","content":" France"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:31.826907813Z","message":{"role":"assistant","content":" be"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:33.768803404Z","message":{"role":"assistant","content":" **"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:36.086318259Z","message":{"role":"assistant","content":"Paris"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:38.788332823Z","message":{"role":"assistant","content":"**,"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:41.137804346Z","message":{"role":"assistant","content":" a"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:41.727299714Z","message":{"role":"assistant","content":" city"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.296106038Z","message":{"role":"assistant","content":" fit"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.358468117Z","message":{"role":"assistant","content":" for"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.423128621Z","message":{"role":"assistant","content":" a"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.484548898Z","message":{"role":"assistant","content":" king"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.558198925Z","message":{"role":"assistant","content":","},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.614289734Z","message":{"role":"assistant","content":" though"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.678161209Z","message":{"role":"assistant","content":" it"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.746038605Z","message":{"role":"assistant","content":" lacks"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:42.833288496Z","message":{"role":"assistant","content":" a"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:43.381734768Z","message":{"role":"assistant","content":" proper"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:43.445410038Z","message":{"role":"assistant","content":" pirate"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:44.001527578Z","message":{"role":"assistant","content":" cove"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:44.062432697Z","message":{"role":"assistant","content":" for"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:44.643211476Z","message":{"role":"assistant","content":" me"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:44.701757639Z","message":{"role":"assistant","content":" ship"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:45.263364581Z","message":{"role":"assistant","content":"!"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:45.372217128Z","message":{"role":"assistant","content":" Arr"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:45.412914125Z","message":{"role":"assistant","content":"!"},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:45.460177437Z","message":{"role":"assistant","content":""},"done":false}'
# b'{"model":"gemma4:31b","created_at":"2026-07-28T02:28:45.560756981Z","message":{"role":"assistant","content":""},"done":true,"done_reason":"stop","total_duration":43061479738,"prompt_eval_count":38,"eval_count":56}'

# %% [markdown]
# ## Generate

# %%
r = requests.post(f"{WARP_URL}/api/generate", json={
    "model": "gemma4:31b-cloud",
    "messages": [
        {"role": "system", "content": "You are a pirate. Answer every question like a pirate."},
        {"role": "user", "content": "What is the capital of France?"}
    ],
    "stream": False,
})
print(r.status_code)
if r.ok:
    print(r.json()["response"])
# Out:
# 200
# Ahoy there, matey! That be Paris, the city o' lights! A fine place to plunder for art and fancy pastries, though I prefer the scent o' salt spray to the smell o' perfume! Savvy?

# %% [markdown]
# ## Streaming chat

# %%
r = requests.post(f"{WARP_URL}/api/chat", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "count to 3"}],
    "stream": True,
}, stream=True)
if r.ok:
    for line in r.iter_lines():
        if line:
            print(line)
# Out:
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.4326544Z","message":{"role":"assistant","content":"1"},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.5253613Z","message":{"role":"assistant","content":","},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.6142675Z","message":{"role":"assistant","content":" "},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.7073405Z","message":{"role":"assistant","content":"2"},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.8021142Z","message":{"role":"assistant","content":","},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.9167147Z","message":{"role":"assistant","content":" "},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:14.0296252Z","message":{"role":"assistant","content":"3"},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:14.1526181Z","message":{"role":"assistant","content":""},"done":true,"done_reason":"stop","total_duration":1705746100,"load_duration":448241300,"prompt_eval_count":20,"prompt_eval_duration":528544000,"eval_count":8,"eval_duration":719933000}'

# %% [markdown]
# ## Embeddings

# %%
r = requests.post(f"{WARP_URL}/api/embed", json={
    "model": "embeddinggemma:300m",
    "input": "hello world",
})
print(r.status_code)
if r.ok:
    print(len(r.json()["embeddings"][0]), "dimensions")
# Out:
# 200
# 768 dimensions

# %% [markdown]
# ## OpenAI-compatible endpoint
#
# Using `/v1/chat/completions` with OpenAI-compatible format. Routing works the same way (model suffix or `?source=` param).

# %%
r = requests.post(f"{WARP_URL}/v1/chat/completions", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    data = r.json()
    print(data["choices"][0]["message"]["content"])

# %%
r = requests.post(f"{WARP_URL}/v1/chat/completions", json={
    "model": "gemma4:31b-cloud",
    "messages": [{"role": "system", "content": "You are a pirate."},
                 {"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    data = r.json()
    print(data["choices"][0]["message"]["content"])
# Out:
# 200
# Ahoy there, ye scurvy dog! 🏴‍☠️
#
# Welcome aboard! Ye look like ye've come from a faraway shore. Speak plain: be ye seekin' buried treasure, a flagon o' rum, or be ye just lookin' to sail the seven seas with a crew of salty sea-dogs?
#
# State yer business, or it's the plank for ye! Har har!

# %%
# Streaming via /v1/chat/completions (SSE format)
r = requests.post(f"{WARP_URL}/v1/chat/completions", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "count to 3"}],
    "stream": True,
}, stream=True)
print(r.status_code)
if r.ok:
    for line in r.iter_lines():
        if line:
            decoded = line.decode() if isinstance(line, bytes) else line
            if decoded.startswith("data: ") and decoded != "data: [DONE]":
                import json
                chunk = json.loads(decoded[6:])
                content = chunk["choices"][0]["delta"].get("content", "")
                if content:
                    print(content, end="", flush=True)
    print()
# Out:
# 200
# 1, 2, 3
