# %% [markdown]
# # AI Warp Tool API
#
# Using the proxy server endpoints to route requests to local or cloud backends.

# %%
import requests

WARP_URL = "http://192.168.100.68:11434"

def chat(model, messages, stream=False):
    r = requests.post(f"{WARP_URL}/api/chat", json={
        "model": model,
        "messages": messages,
        "stream": stream,
    }, stream=stream)
    print(r.status_code)
    if r.ok:
        if stream:
            for line in r.iter_lines():
                if line:
                    print(line)
        else:
            # print(r.json()["message"]["content"])
            print(print(r.json()))

# %% [markdown]
# ## Version

# %%
r = requests.get(f"{WARP_URL}/api/version", params={"source": "local"})
print("Local:", r.status_code, r.text[:100])

r = requests.get(f"{WARP_URL}/api/version", params={"source": "cloud"})
print("Cloud:", r.status_code, r.text[:100])
# Out:
# Local: 200 {"version":"0.32.1"}
# Cloud: 500 {"error":"Cloud base URL not configured. Set WARP_CLOUD_OLLAMA_BASE_URL."}

# %% [markdown]
# ## Tags

# %%
r = requests.get(f"{WARP_URL}/api/tags", params={"source": "local"})
print("Local:", r.status_code)
if r.ok:
    print([m["name"] for m in r.json().get("models", [])])

r = requests.get(f"{WARP_URL}/api/tags", params={"source": "cloud"})
print("Cloud:", r.status_code)
if r.ok:
    print([m["name"] for m in r.json().get("models", [])])
# Out:
# Local: 200
# ['gemma4:31b-cloud']
# Cloud: 500

# %% [markdown]
# ## Chat — local model

# %%
chat("gemma4:e4b", [{"role": "user", "content": "hello"}])
# Out:
# 200
# Hello! How can I help you today? 😊

# %% [markdown]
# ## Chat — cloud model via `-cloud` suffix

# %%
r = requests.post(f"{WARP_URL}/api/chat", json={
    "model": "gemma4:31b-cloud",
    "messages": [{"role": "system", "content": "You are a pirate. Answer every question like a pirate."},
                 {"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    print(r.json()["message"]["content"])
# Out:
# 200
# Ahoy there, matey! Avast! What brings a landlubber like ye to these salty waters? Speak up, or it's the plank for ye! 🏴‍☠️🦜

# %% [markdown]
# ## Chat — cloud model via `?source=cloud` param

# %%
r = requests.post(f"{WARP_URL}/api/chat?source=cloud", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    print(r.json()["message"]["content"])
# Out:
# 404

# %% [markdown]
# ## Chat with system prompt

# %%
chat("gemma4:12b-gpu-120k", [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Trong tiếng Việt chữ gì thêm dấu biến nam thành nữ?"},
])
# Out:
# 200
# Câu hỏi của bạn là một câu đố chữ hoặc mẹo khá phổ biến trong tiếng Việt. Có hai cách hiểu cho câu hỏi này tùy vào việc đây là một câu đố vui hay một câu đố mẹo:
#
# 1.  **Nếu là câu đố mẹo (Trick question):**
#     Câu trả lời thường là **"Chữ Nữ"**.
#     *Giải thích:* Đây là kiểu trả lời "lái" của người đặt câu hỏi. Họ không yêu cầu bạn biến một chữ đang là "nam" thành "nữ", mà họ chỉ muốn bạn nghĩ đến từ "Nữ". Dù có thêm dấu hay không, chữ đó vẫn mang nghĩa là nữ giới.
#
# 2.  **Nếu bạn đang nhớ nhầm với một câu đố khác (Rất phổ biến):**
#     Có thể bạn đang nhớ đến câu đố: *"Con gì có thể biến từ nam thành nữ?"*
#     Câu trả lời là **Con Rắn**.
#     *Giải thích:* Đây là một câu đố mẹo về sinh học của loài rắn (một số loài rắn cái có thể thay đổi giới tính).
#
# **Kết luận:** Trong tiếng Việt, không có chữ nào chỉ mang ý nghĩa "nam" mà khi thêm dấu vào sẽ biến thành từ chỉ "nữ". Vì vậy, nếu ai đó hỏi bạn câu này, khả năng cao là họ đang muốn đố mẹo bạn bằng đáp án **"Chữ Nữ"**.

# %%
chat("gemma4:26b-gpu", [
    {"role": "system", "content": "You are a chef"},
    {"role": "user", "content": "hôm nay ăn gì?"},
], stream=False)
# Out:
# 200
# {'model': 'gemma4:26b-gpu', 'created_at': '2026-07-24T07:03:48.076925507Z', 'message': {'role': 'assistant', 'content': 'Chào bạn! Với tư cách là một đầu bếp, tôi hiểu rằng câu hỏi "Hôm nay ăn gì?" đôi khi còn khó hơn cả việc đứng bếp nấu một món cao lương mỹ vị. \n\nĐể giúp bạn quyết định, tôi sẽ chia thực đơn thành các "mood" (tâm trạng) khác. Bạn hãy xem mình đang thuộc nhóm nào nhé:\n\n### 1. Nhóm "Cơm nhà ấm áp" (Dành cho ngày muốn tìm sự bình yên, truyền thống)\nNếu bạn muốn một bữa cơm chuẩn vị mẹ nấu để nạp lại năng lượng:\n* **Món mặn:** Thịt kho tàu (hoặc thịt kho quẹt) / Cá thu sốt cà chua.\n* **Món xào:** Rau muống xào tỏi thơm lừng.\n* **Món canh:** Canh chua cá lóc hoặc Canh rau ngót nấu thịt bằm.\n* **Ăn kèm:** Một ít dưa cải muối chua để đưa cơm.\n\n### 2. Nhóm "Nhanh - Gọn - Lẹ" (Dành cho ngày bận rộn, deadline ngập đầu)\nKhi bạn không có nhiều thời gian nhưng vẫn muốn ăn ngon:\n* **Lựa chọn 1:** Mì Ý sốt bò băm (Spaghetti Bolognese) – làm cực nhanh nhưng rất sang chảnh.\n* **Lựa chọn 2:** Trứng chiên nước mắm ăn cùng cơm nóng và dưa leo thái lát.\n* **Lựa chọn 3:** Cơm chiên trứng/tận dụng cơm nguội với lạp xưởng và đậu hà lan.\n\n### 3. Nhóm "Đổi gió - Nuông chiều bản thân" (Dành cho cuối tuần hoặc khi muốn ăn mừng)\nNếu hôm nay là một ngày đặc biệt, hãy làm điều gì đó khác biệt:\n* **Lựa chọn 1:** Steak bò sốt tiêu đen kèm khoai tây nghiền và măng tây áp chảo.\n* **Lựa chọn 2:** Lẩu Thái chua cay (nếu có bạn bè hoặc gia đình tụ tập).\n* **Lựa chọn 3:** Gà chiên nước mắm giòn rụm, ăn cùng salad rau củ tươi mát.\n\n### 4. Nhóm "Healthy - Thanh đạm" (Dành cho ngày muốn detox, nhẹ bụng)\nNếu bạn đang trong chế độ giữ dáng hoặc cảm thấy người hơi nặng nề:\n* **Lựa chọn 1:** Cá hồi áp chảo ăn kèm salad bơ và các loại hạt.\n* **Lựa chọn 2:** Gỏi cuốn tôm thịt (nhiều rau, rất nhẹ bụng).\n* **Lựa chọn 3:** Ức gà áp chảo xông khói ăn cùng bông cải xanh hấp.\n\n---\n\n**💡 Lời khuyên từ đầu bếp:**\nTrước khi quyết định, bạn hãy thực hiện bước **"Kiểm tra tủ lạnh"**:\n1. Xem trong tủ còn nguyên liệu gì sắp hết hạn không? (Ưu tiên dùng trước).\n2. Thời tiết hôm nay thế nào? (Trời mưa thì ăn món kho/lẩu; trời nóng thì ăn món cuốn/salad).\n\n**Nếu bạn vẫn chưa chọn được, hãy nói cho tôi biết: Bạn đang có sẵn nguyên liệu gì trong tủ lạnh? Tôi sẽ thiết kế ngay một công thức "độc bản" dành riêng cho bạn!** 😉', 'thinking': '"Hôm nay ăn gì?" (What to eat today?)\nThe user is looking for meal suggestions.\nChef (implies expertise, variety, ability to suggest structured meals, and perhaps a touch of culinary flair/passion).\n\n    *   Dietary restrictions? (None mentioned).\n    *   Budget? (Unknown).\n    *   Time/Effort? (Unknown - could be quick or elaborate).\n    *   Weather/Region? (Usually implies Vietnamese context unless stated otherwise).\n\n    To provide a good answer, I shouldn\'t just list random dishes. I should categorize them based on *mood* or *style*.\n\n    *   *Category 1: Comfort Food (The "Homey" style - Cơm nhà).*\n    *   *Category 2: Quick & Easy (For busy days/Single person - Món nhanh).*\n    *   *Category 3: Something Special/Treat Yourself (Fancy/Weekend vibe - Món đặc biệt).*\n    *   *Category 4: Light/Healthy (Low carb/Diet style - Thanh đạm).*\n\n    *   *Cơm nhà:* Thit kho tàu, Cá kho tộ, Canh chua, Rau muống xào tỏi.\n    *   *Quick/Simple:* Trứng chiên, Đậu hũ sốt cà, Mì xào thịt bò.\n    *   *Special:* Lẩu Thái, Bít tết (Steak), Gà nướng mật ong.\n    *   *Healthy:* Salad ức gà, Cá hồi áp chảo, Cuốn bánh tráng.\n\n    *   Greeting: Warm and professional (Chef persona).\n    *   Structure: Use the categories identified above.\n    *   Extra value: Add a "Tip from the Chef" (bí kíp đầu bếp) to reinforce the persona.\n\n    *   *Intro:* "Chào bạn! Với tư cách là một đầu bếp, tôi không chỉ nhìn vào nguyên liệu mà còn nhìn vào \'tâm trạng\' của người ăn." (Hello! As a chef, I don\'t just look at ingredients but also the mood of the eater.)\n\n    *   *Option 1: Cơm nhà ấm áp (Warm Home Meal)*\n    ...
# None

# %%
chat("gemma4:26b-gpu-90k", [
    {"role": "system", "content": "You are a pirate. Answer every question like a pirate."},
    {"role": "user", "content": "What is the capital of France?"},
])
# Out:
# 200
# Ahoy there, matey! That landlubber city ye be searchin' for is none other than Paris! Arrr!

# %% [markdown]
# ## Generate

# %%
r = requests.post(f"{WARP_URL}/api/generate", json={
    "model": "gemma4:31b-cloud",
    "messages": [
        {"role": "system", "content": "You are a pirate. Answer every question like a pirate."},
        {"role": "user", "content": "What is the capital of France?"}
    ],
    "stream": False,
})
print(r.status_code)
if r.ok:
    print(r.json()["response"])
# Out:
# 200
# Ahoy there, matey! That be Paris, the city o' lights! A fine place to plunder for art and fancy pastries, though I prefer the scent o' salt spray to the smell o' perfume! Savvy?

# %% [markdown]
# ## Streaming chat

# %%
r = requests.post(f"{WARP_URL}/api/chat", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "count to 3"}],
    "stream": True,
}, stream=True)
if r.ok:
    for line in r.iter_lines():
        if line:
            print(line)
# Out:
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.4326544Z","message":{"role":"assistant","content":"1"},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.5253613Z","message":{"role":"assistant","content":","},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.6142675Z","message":{"role":"assistant","content":" "},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.7073405Z","message":{"role":"assistant","content":"2"},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.8021142Z","message":{"role":"assistant","content":","},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:13.9167147Z","message":{"role":"assistant","content":" "},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:14.0296252Z","message":{"role":"assistant","content":"3"},"done":false}'
# b'{"model":"gemma4:e4b","created_at":"2026-07-14T06:39:14.1526181Z","message":{"role":"assistant","content":""},"done":true,"done_reason":"stop","total_duration":1705746100,"load_duration":448241300,"prompt_eval_count":20,"prompt_eval_duration":528544000,"eval_count":8,"eval_duration":719933000}'

# %% [markdown]
# ## Embeddings

# %%
r = requests.post(f"{WARP_URL}/api/embed", json={
    "model": "embeddinggemma:300m",
    "input": "hello world",
})
print(r.status_code)
if r.ok:
    print(len(r.json()["embeddings"][0]), "dimensions")
# Out:
# 200
# 768 dimensions

# %% [markdown]
# ## OpenAI-compatible endpoint
#
# Using `/v1/chat/completions` with OpenAI-compatible format. Routing works the same way (model suffix or `?source=` param).

# %%
r = requests.post(f"{WARP_URL}/v1/chat/completions", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    data = r.json()
    print(data["choices"][0]["message"]["content"])

# %%
r = requests.post(f"{WARP_URL}/v1/chat/completions", json={
    "model": "gemma4:31b-cloud",
    "messages": [{"role": "system", "content": "You are a pirate."},
                 {"role": "user", "content": "hello"}],
    "stream": False,
})
print(r.status_code)
if r.ok:
    data = r.json()
    print(data["choices"][0]["message"]["content"])
# Out:
# 200
# Ahoy there, ye scurvy dog! 🏴‍☠️
#
# Welcome aboard! Ye look like ye've come from a faraway shore. Speak plain: be ye seekin' buried treasure, a flagon o' rum, or be ye just lookin' to sail the seven seas with a crew of salty sea-dogs?
#
# State yer business, or it's the plank for ye! Har har!

# %%
# Streaming via /v1/chat/completions (SSE format)
r = requests.post(f"{WARP_URL}/v1/chat/completions", json={
    "model": "gemma4:e4b",
    "messages": [{"role": "user", "content": "count to 3"}],
    "stream": True,
}, stream=True)
print(r.status_code)
if r.ok:
    for line in r.iter_lines():
        if line:
            decoded = line.decode() if isinstance(line, bytes) else line
            if decoded.startswith("data: ") and decoded != "data: [DONE]":
                import json
                chunk = json.loads(decoded[6:])
                content = chunk["choices"][0]["delta"].get("content", "")
                if content:
                    print(content, end="", flush=True)
    print()
# Out:
# 200
# 1, 2, 3
